# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Demo 8.3: Web Scraping
#
# INSTRUCTIONS:
#
# - Run the cells
# - Observe and understand the results

# %% [markdown]
# # Web Scraping in Python (using BeautifulSoup)

# %% [markdown]
# # Basics HTML
# Before starting with the code, let’s understand the basics of HTML and some rules of scraping.
#
# ## HTML tags
# Below is the source code for a simple HTML webpage.
#
#     <!DOCTYPE html>
#     <html>
#         <head>
#         </head>
#         <body>
#             <h1> First Scraping </h1>
#             <p> Hello World </p>
#         <body>
#     </html>
#
# This is the basic syntax of an HTML webpage. Every `<tag>` serves a block inside the webpage:
# 1. `<!DOCTYPE html>` HTML documents must start with a type declaration.
# 2. The HTML document is contained between `<html>` and `</html>`.
# 3. The meta and script declaration of the HTML document is between `<head>` and `</head>`.
# 4. The visible part of the HTML document is between `<body>` and `</body>` tags.
# 5. Title headings are defined with the `<h1>` through `<h6>` tags.
# 6. Paragraphs are defined with the `<p>` tag.
#
# Other useful tags include `<a>` for hyperlinks, `<table>` for tables, `<tr>` for table rows, and `<td>` for table columns.
#
# Also, HTML tags sometimes come with `id` or `class` attributes. The `id` attribute specifies a unique id for an HTML tag and the value must be unique within the HTML document. The `class` attribute is used to define equal styles for HTML tags with the same class. We can make use of these ids and classes to help us locate the data we want.
#
# ## Scraping Rules
# 1. **Always** check a website’s **Terms and Conditions** before you scrape it. Be careful to read the statements about legal use of data. Usually, the retrieved data should not be used for commercial purposes.
# 2. **Do not** request data from the website too aggressively with a program (also known as spamming), as this may break the website. Make sure the program behaves in a reasonable manner (i.e. acts like a human). One request for one webpage per second is good practice.
# 3. The layout of a website may change from time to time, so make sure to revisit the site and rewrite the code as needed

# %% [markdown]
# ## Inspecting the Page
# Let’s take one page from the **Memory Alpha** website as an example.
#
# To investigate some relationships let's get the links from this page.

# %% [markdown]
# Open the web page on [Prinadora](https://memory-alpha.fandom.com/wiki/Prinadora) with the browser and inspect it.
#
# Hover the cursor on the text and follow the shaded box surrounding the main text.
#
# From the result, check the navigation menu text inside a couple of levels of HTML tags, which is `<div class="fandom-sticky-header">` → `<nav class="fandom-community-header__local-navigation">`.
#
# This section of the data is what we focus on.

# %%
# ! pip3 install regex

# %%
# ! pip3 install bs4

# %%
## Import Libraries
import regex as re

from urllib.parse import unquote
import urllib3
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Define the content to retrieve (webpage's URL)

# %%
# specify the url
quote_page = 'http://memory-alpha.wikia.com/wiki/Prinadora'

# %% [markdown]
# ### Retrieve the page
# - Require Internet connection

# %%
# query the website and return the html to the variable ‘page’
http = urllib3.PoolManager()
r = http.request('GET', quote_page)
if r.status == 200:
    page = r.data
    print('Type of the variable \'page\':', page.__class__.__name__)
    print('Page Retrieved. Request Status: %d, Page Size: %d' % (r.status, len(page)))
else:
    print('Some problem occurred. Request Status: %s' % r.status)
# Out:
# Type of the variable 'page': bytes
# Page Retrieved. Request Status: 200, Page Size: 421899

# %% [markdown]
# ### Convert the stream of bytes into a BeautifulSoup representation

# %%
# parse the html using beautiful soup and store in variable `soup`
soup = BeautifulSoup(page, 'html.parser')
print('Type of the variable \'soup\':', soup.__class__.__name__)
# Out:
# Type of the variable 'soup': BeautifulSoup

# %% [markdown]
# ### Check the content
# - The HTML source
# - Includes all tags and scripts
# - Can be long!

# %%
print(soup.prettify()[:980])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Prinadora | Memory Alpha | Fandom
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Prinadora","wgTitle":"Prinadora","wgCurRevisionId":2846125,"wgRevisionId":2846125,"wgArticleId":8581,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Ferengi"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","

# %% [markdown]
# ### Check the HTML's Title

# %%
print('Title tag :%s:' % soup.title)
print('Title text:%s:' % soup.title.string)
# Out:
# Title tag :<title>Prinadora | Memory Alpha | Fandom</title>:
# Title text:Prinadora | Memory Alpha | Fandom:

# %% [markdown]
# ###  nav tag
# - This page uses the tag `nav` for navigation links
#
#         <nav class="fandom-community-header__local-navigation">

# %%
tag = 'nav'
nav = soup.find_all(tag)[0]
print('Type of the variable \'article\':', nav.__class__.__name__)
# Out:
# Type of the variable 'article': Tag

# %% [markdown]
# ### Get some of the text
# - Plain text without HTML tags

# %%
# show the first 500 characters after removing redundant newlines
print(re.sub(r'\n\n+', '\n', nav.text)[:500])

# print(re.sub(r'\n\n+', '', nav.text)[:500])
# Out:
#  Explore
#
#  Main Page
#  Discuss
# All Pages
# Community
# Portals
#
# People
#
# Bajorans
# Borg
# Ferengi
# Humans
# Klingons
# Romulans
# Vulcans
# Starfleet personnel
# Society & Culture
#
# Borg
# Cardassian Union
# Dominion
# Ferengi Alliance
# Federation
# Klingon Empire
# Romulan Empire
# Vulcan
# Science
#
# Alpha Quadrant
# Beta Quadrant
# Gamma Quadrant
# Delta Quadrant
# Technology
#
# Spacecraft
# Starships
# Spacecraft classes
# Starship classes
# Stations
# All technology
# The Alternate Reality
#
# History
# People
# Places
# Things
# Spacecraft
# Starfleet

# %% [markdown]
# ### Find the links in the text

# %%
# identify the type of tag to retrieve
tag = 'a'
# create a list with the links from the `<a>` tag
tag_list = [t.get('href') for t in nav.find_all(tag)]
tag_list
# Out:
# ['#',
#  'https://memory-alpha.fandom.com/wiki/Portal:Main',
#  '/f',
#  'https://memory-alpha.fandom.com/wiki/Special:AllPages',
#  'https://memory-alpha.fandom.com/wiki/Special:Community',
#  'https://memory-alpha.fandom.com/wiki/Category:Memory_Alpha_portals',
#  'https://memory-alpha.fandom.com/wiki/Portal:People',
#  'https://memory-alpha.fandom.com/wiki/Category:Bajorans',
#  'https://memory-alpha.fandom.com/wiki/Category:Borg',
#  'https://memory-alpha.fandom.com/wiki/Category:Ferengi',
#  'https://memory-alpha.fandom.com/wiki/Category:Humans',
#  'https://memory-alpha.fandom.com/wiki/Category:Klingons',
#  'https://memory-alpha.fandom.com/wiki/Category:Romulans',
#  'https://memory-alpha.fandom.com/wiki/Category:Vulcans',
#  'https://memory-alpha.fandom.com/wiki/Category:Starfleet_personnel',
#  'https://memory-alpha.fandom.com/wiki/Portal:Society_and_Culture',
#  'https://memory-alpha.fandom.com/wiki/Borg',
#  'https://memory-alpha.fandom.com/wiki/Cardassian_Union',
#  'https://memory-alpha.fandom.com/wiki/Dominion',
#  'https://memory-alpha.fandom.com/wiki/Ferengi_Alliance',
#  'https://memory-alpha.fandom.com/wiki/United_Federation_of_Planets',
#  'https://memory-alpha.fandom.com/wiki/Klingon_Empire',
#  'https://memory-alpha.fandom.com/wiki/Romulan_Star_Empire',
#  'https://memory-alpha.fandom.com/wiki/Vulcan',
#  'https://memory-alpha.fandom.com/wiki/Portal:Science',
#  'https://memory-alpha.fandom.com/wiki/Alpha_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Beta_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Gamma_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Delta_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Portal:Technology',
#  'https://memory-alpha.fandom.com/wiki/Category:Spacecraft',
#  'https://memory-alpha.fandom.com/wiki/Category:Starships',
#  'https://memory-alpha.fandom.com/wiki/Category:Spacecraft_classes',
#  'https://memory-alpha.fandom.com/wiki/Category:Starship_classes',
#  'https://memory-alpha.fandom.com/wiki/Category:Stations',
#  'https://memory-alpha.fandom.com/wiki/Category:Technology',
#  'https://memory-alpha.fandom.com/wiki/Portal:Alternate_Reality',
#  'https://memory-alpha.fandom.com/wiki/Alternate_reality',
#  'https://memory-alpha.fandom.com/wiki/Category:Alternate_reality_inhabitants',
#  'https://memory-alpha.fandom.com/wiki/Category:Locations_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Category:Alternate_reality',
#  'https://memory-alpha.fandom.com/wiki/Category:Spacecraft_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Category:Starfleet_personnel_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Portal:Star_Trek',
#  'https://memory-alpha.fandom.com/wiki/Category:Production_timeline',
#  'https://memory-alpha.fandom.com/wiki/Category:Production_calendar',
#  'https://memory-alpha.fandom.com/wiki/Category:Performers',
#  'https://memory-alpha.fandom.com/wiki/Studio_model',
#  'https://memory-alpha.fandom.com/wiki/Retroactive_continuity',
#  'https://memory-alpha.fandom.com/wiki/Deleted_scene',
#  'https://memory-alpha.fandom.com/wiki/Category:Unused_production_material',
#  'https://memory-alpha.fandom.com/wiki/Portal:Merchandise',
#  'https://memory-alpha.fandom.com/wiki/DVD',
#  'https://memory-alpha.fandom.com/wiki/Blu-ray_Disc',
#  'https://memory-alpha.fandom.com/wiki/Digital_formats',
#  'https://memory-alpha.fandom.com/wiki/Novels',
#  'https://memory-alpha.fandom.com/wiki/Comics',
#  'https://memory-alpha.fandom.com/wiki/Calendars',
#  'https://memory-alpha.fandom.com/wiki/Category:Collectibles',
#  'https://memory-alpha.fandom.com/wiki/Portal:TV_and_films',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_Enterprise',
#  'https://memory-alpha.fandom.com/wiki/Jonathan_Archer',
#  'https://memory-alpha.fandom.com/wiki/T%27Pol',
#  'https://memory-alpha.fandom.com/wiki/Charles_Tucker_III',
#  'https://memory-alpha.fandom.com/wiki/Malcolm_Reed',
#  'https://memory-alpha.fandom.com/wiki/Phlox',
#  'https://memory-alpha.fandom.com/wiki/Hoshi_Sato',
#  'https://memory-alpha.fandom.com/wiki/Travis_Mayweather',
#  'https://memory-alpha.fandom.com/wiki/Thy%27lek_Shran',
#  'https://memory-alpha.fandom.com/wiki/Maxwell_Forrest',
#  'https://memory-alpha.fandom.com/wiki/Enterprise_(NX-01)',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_Discovery',
#  'https://memory-alpha.fandom.com/wiki/Michael_Burnham',
#  'https://memory-alpha.fandom.com/wiki/Saru',
#  'https://memory-alpha.fandom.com/wiki/Paul_Stamets',
#  'https://memory-alpha.fandom.com/wiki/Sylvia_Tilly',
#  'https://memory-alpha.fandom.com/wiki/Hugh_Culber',
#  'https://memory-alpha.fandom.com/wiki/Nhan',
#  'https://memory-alpha.fandom.com/wiki/Adira_Tal',
#  'https://memory-alpha.fandom.com/wiki/Cleveland_Booker',
#  'https://memory-alpha.fandom.com/wiki/Philippa_Georgiou_(mirror)',
#  'https://memory-alpha.fandom.com/wiki/USS_Discovery',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_Strange_New_Worlds',
#  'https://memory-alpha.fandom.com/wiki/Christopher_Pike',
#  'https://memory-alpha.fandom.com/wiki/Una',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_The_Original_Series',
#  'https://memory-alpha.fandom.com/wiki/James_T._Kirk',
#  'https://memory-alpha.fandom.com/wiki/Spock',
#  'https://memory-alpha.fandom.com/wiki/Leonard_McCoy',
#  'https://memory-alpha.fandom.com/wiki/Montgomery_Scott',
#  'https://memory-alpha.fandom.com/wiki/Hikaru_Sulu',
#  'https://memory-alpha.fandom.com/wiki/Nyota_Uhura',
#  'https://memory-alpha.fandom.com/wiki/Pavel_Chekov',
#  'https://memory-alpha.fandom.com/wiki/Christine_Chapel',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701)',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-A)',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_films',
#  'https://memory-alpha.fandom.com/wiki/James_T._Kirk_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Spock_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Leonard_McCoy_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Nyota_Uhura_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Montgomery_Scott_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Hikaru_Sulu_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Pavel_Chekov_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Christopher_Pike_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701_alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-A_alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_films',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_The_Motion_Picture',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_II:_The_Wrath_of_Khan',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_III:_The_Search_for_Spock',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_IV:_The_Voyage_Home',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_V:_The_Final_Frontier',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_VI:_The_Undiscovered_Country',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_(film)',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_Into_Darkness',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_Beyond',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_XIV',
#  'https://memory-alpha.fandom.com/wiki/Category:Undeveloped_projects',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_Phase_II',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_Planet_of_the_Titans',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_III_(Gene_Roddenberry)',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_The_First_Adventure',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_The_Beginning',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_4_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Portal:TV_and_films',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_The_Next_Generation',
#  'https://memory-alpha.fandom.com/wiki/William_T._Riker',
#  'https://memory-alpha.fandom.com/wiki/Data',
#  'https://memory-alpha.fandom.com/wiki/Geordi_La_Forge',
#  'https://memory-alpha.fandom.com/wiki/Worf',
#  'https://memory-alpha.fandom.com/wiki/Deanna_Troi',
#  'https://memory-alpha.fandom.com/wiki/Beverly_Crusher',
#  'https://memory-alpha.fandom.com/wiki/Wesley_Crusher',
#  'https://memory-alpha.fandom.com/wiki/Natasha_Yar',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-D)',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-E)',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_Deep_Space_Nine',
#  'https://memory-alpha.fandom.com/wiki/Benjamin_Sisko',
#  'https://memory-alpha.fandom.com/wiki/Kira_Nerys',
#  'https://memory-alpha.fandom.com/wiki/Miles_O%27Brien',
#  'https://memory-alpha.fandom.com/wiki/Odo',
#  'https://memory-alpha.fandom.com/wiki/Jadzia_Dax',
#  'https://memory-alpha.fandom.com/wiki/Julian_Bashir',
#  'https://memory-alpha.fandom.com/wiki/Quark',
#  'https://memory-alpha.fandom.com/wiki/Jake_Sisko',
#  'https://memory-alpha.fandom.com/wiki/Ezri_Dax',
#  'https://memory-alpha.fandom.com/wiki/Deep_Space_9',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_Voyager',
#  'https://memory-alpha.fandom.com/wiki/Kathryn_Janeway',
#  'https://memory-alpha.fandom.com/wiki/Chakotay',
#  'https://memory-alpha.fandom.com/wiki/Tuvok',
#  'https://memory-alpha.fandom.com/wiki/Tom_Paris',
#  'https://memory-alpha.fandom.com/wiki/B%27Elanna_Torres',
#  'https://memory-alpha.fandom.com/wiki/Harry_Kim',
#  'https://memory-alpha.fandom.com/wiki/The_Doctor',
#  'https://memory-alpha.fandom.com/wiki/Neelix',
#  'https://memory-alpha.fandom.com/wiki/Kes',
#  'https://memory-alpha.fandom.com/wiki/USS_Voyager',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_Lower_Decks',
#  'https://memory-alpha.fandom.com/wiki/Beckett_Mariner',
#  'https://memory-alpha.fandom.com/wiki/Brad_Boimler',
#  'https://memory-alpha.fandom.com/wiki/D%27Vana_Tendi',
#  'https://memory-alpha.fandom.com/wiki/Sam_Rutherford',
#  'https://memory-alpha.fandom.com/wiki/Carol_Freeman',
#  'https://memory-alpha.fandom.com/wiki/Jack_Ransom',
#  'https://memory-alpha.fandom.com/wiki/Shaxs',
#  'https://memory-alpha.fandom.com/wiki/T%27Ana',
#  'https://memory-alpha.fandom.com/wiki/USS_Cerritos',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_Picard',
#  'https://memory-alpha.fandom.com/wiki/Jean-Luc_Picard',
#  'https://memory-alpha.fandom.com/wiki/Seven_of_Nine',
#  'https://memory-alpha.fandom.com/wiki/Agnes_Jurati',
#  'https://memory-alpha.fandom.com/wiki/Soji_Asha',
#  'https://memory-alpha.fandom.com/wiki/Elnor',
#  'https://memory-alpha.fandom.com/wiki/Raffaela_Musiker',
#  'https://memory-alpha.fandom.com/wiki/Crist%C3%B3bal_Rios',
#  'https://memory-alpha.fandom.com/wiki/Narek',
#  'https://memory-alpha.fandom.com/wiki/Narissa',
#  'https://memory-alpha.fandom.com/wiki/La_Sirena',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_Prodigy',
#  'https://memory-alpha.fandom.com/wiki/Dal_R%27El',
#  'https://memory-alpha.fandom.com/wiki/Gwyn',
#  'https://memory-alpha.fandom.com/wiki/Jankom_Pog',
#  'https://memory-alpha.fandom.com/wiki/Zero',
#  'https://memory-alpha.fandom.com/wiki/Rok-Tahk',
#  'https://memory-alpha.fandom.com/wiki/Murf',
#  'https://memory-alpha.fandom.com/wiki/Drednok',
#  'https://memory-alpha.fandom.com/wiki/The_Diviner',
#  'https://memory-alpha.fandom.com/wiki/Kathryn_Janeway_(hologram)',
#  'https://memory-alpha.fandom.com/wiki/USS_Protostar',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_films',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_Generations',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_First_Contact',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek:_Insurrection',
#  'https://memory-alpha.fandom.com/wiki/Star_Trek_Nemesis',
#  'https://memory-alpha.fandom.com/wiki/Special:RecentChanges',
#  'https://memory-alpha.fandom.com/wiki/Special:Community',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Introduction',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Archivists',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Administrators',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Projects',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Babel',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Ten_Forward',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Reference_Desk',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Discord',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Social_media',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Pages_to_be...',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Utilities',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Pages_needing_attention',
#  'https://memory-alpha.fandom.com/wiki/Category:Memory_Alpha_pages_needing_citation',
#  'https://memory-alpha.fandom.com/wiki/Category:Memory_Alpha_incomplete_articles',
#  'https://memory-alpha.fandom.com/wiki/Category:Memory_Alpha_stubs',
#  'https://memory-alpha.fandom.com/wiki/Category:Memory_Alpha_files_needing_attention',
#  'https://memory-alpha.fandom.com/wiki/Category:Memory_Alpha_files_needing_citation',
#  'https://memory-alpha.fandom.com/wiki/Special:UnusedFiles',
#  'https://memory-alpha.fandom.com/wiki/Special:Watchlist',
#  'https://memory-alpha.fandom.com/wiki/Special:Log',
#  'https://memory-alpha.fandom.com/wiki/Special:NewPages',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Pages_for_deletion',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Files_for_deletion',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Peer_review',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Featured_article_nominations',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Featured_article_reviews',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Policies_and_guidelines',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Manual_of_Style',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Copyrights',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Content_policy',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Resource_policy',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Cite_your_sources',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Point_of_view',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:File_use_policy',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Spoiler_policy',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:FAQ',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:General_FAQ',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Contributions_FAQ',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Editing_FAQ',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Content_policy_FAQ',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Resource_policy_FAQ',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Administration_FAQ',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Contact_us',
#  'https://memory-alpha.fandom.com/wiki/Memory_Alpha:Privacy_policy',
#  'https://memory-alpha.fandom.com/wiki/MA_Help:Contents',
#  'https://memory-alpha.fandom.com/wiki/MA_Help:Logging_in',
#  'https://memory-alpha.fandom.com/wiki/MA_Help:Editing',
#  'https://memory-alpha.fandom.com/wiki/MA_Help:Edit_summary',
#  'https://memory-alpha.fandom.com/wiki/MA_Help:Wiki_markup',
#  'https://memory-alpha.fandom.com/wiki/MA_Help:Template',
#  'https://memory-alpha.fandom.com/wiki/MA_Help:Category',
#  'https://memory-alpha.fandom.com/wiki/MA_Help:Talk_pages']

# %%
# keep only the links to the wiki itself
tag_list = [t[37:] for t in tag_list if (t) and ('/wiki/' in t)]
tag_list
# Out:
# ['Portal:Main',
#  'Special:AllPages',
#  'Special:Community',
#  'Category:Memory_Alpha_portals',
#  'Portal:People',
#  'Category:Bajorans',
#  'Category:Borg',
#  'Category:Ferengi',
#  'Category:Humans',
#  'Category:Klingons',
#  'Category:Romulans',
#  'Category:Vulcans',
#  'Category:Starfleet_personnel',
#  'Portal:Society_and_Culture',
#  'Borg',
#  'Cardassian_Union',
#  'Dominion',
#  'Ferengi_Alliance',
#  'United_Federation_of_Planets',
#  'Klingon_Empire',
#  'Romulan_Star_Empire',
#  'Vulcan',
#  'Portal:Science',
#  'Alpha_Quadrant',
#  'Beta_Quadrant',
#  'Gamma_Quadrant',
#  'Delta_Quadrant',
#  'Portal:Technology',
#  'Category:Spacecraft',
#  'Category:Starships',
#  'Category:Spacecraft_classes',
#  'Category:Starship_classes',
#  'Category:Stations',
#  'Category:Technology',
#  'Portal:Alternate_Reality',
#  'Alternate_reality',
#  'Category:Alternate_reality_inhabitants',
#  'Category:Locations_(alternate_reality)',
#  'Category:Alternate_reality',
#  'Category:Spacecraft_(alternate_reality)',
#  'Category:Starfleet_personnel_(alternate_reality)',
#  'Portal:Star_Trek',
#  'Category:Production_timeline',
#  'Category:Production_calendar',
#  'Category:Performers',
#  'Studio_model',
#  'Retroactive_continuity',
#  'Deleted_scene',
#  'Category:Unused_production_material',
#  'Portal:Merchandise',
#  'DVD',
#  'Blu-ray_Disc',
#  'Digital_formats',
#  'Novels',
#  'Comics',
#  'Calendars',
#  'Category:Collectibles',
#  'Portal:TV_and_films',
#  'Star_Trek:_Enterprise',
#  'Jonathan_Archer',
#  'T%27Pol',
#  'Charles_Tucker_III',
#  'Malcolm_Reed',
#  'Phlox',
#  'Hoshi_Sato',
#  'Travis_Mayweather',
#  'Thy%27lek_Shran',
#  'Maxwell_Forrest',
#  'Enterprise_(NX-01)',
#  'Star_Trek:_Discovery',
#  'Michael_Burnham',
#  'Saru',
#  'Paul_Stamets',
#  'Sylvia_Tilly',
#  'Hugh_Culber',
#  'Nhan',
#  'Adira_Tal',
#  'Cleveland_Booker',
#  'Philippa_Georgiou_(mirror)',
#  'USS_Discovery',
#  'Star_Trek:_Strange_New_Worlds',
#  'Christopher_Pike',
#  'Una',
#  'Star_Trek:_The_Original_Series',
#  'James_T._Kirk',
#  'Spock',
#  'Leonard_McCoy',
#  'Montgomery_Scott',
#  'Hikaru_Sulu',
#  'Nyota_Uhura',
#  'Pavel_Chekov',
#  'Christine_Chapel',
#  'USS_Enterprise_(NCC-1701)',
#  'USS_Enterprise_(NCC-1701-A)',
#  'Star_Trek_films',
#  'James_T._Kirk_(alternate_reality)',
#  'Spock_(alternate_reality)',
#  'Leonard_McCoy_(alternate_reality)',
#  'Nyota_Uhura_(alternate_reality)',
#  'Montgomery_Scott_(alternate_reality)',
#  'Hikaru_Sulu_(alternate_reality)',
#  'Pavel_Chekov_(alternate_reality)',
#  'Christopher_Pike_(alternate_reality)',
#  'USS_Enterprise_(NCC-1701_alternate_reality)',
#  'USS_Enterprise_(NCC-1701-A_alternate_reality)',
#  'Star_Trek_films',
#  'Star_Trek:_The_Motion_Picture',
#  'Star_Trek_II:_The_Wrath_of_Khan',
#  'Star_Trek_III:_The_Search_for_Spock',
#  'Star_Trek_IV:_The_Voyage_Home',
#  'Star_Trek_V:_The_Final_Frontier',
#  'Star_Trek_VI:_The_Undiscovered_Country',
#  'Star_Trek_(film)',
#  'Star_Trek_Into_Darkness',
#  'Star_Trek_Beyond',
#  'Star_Trek_XIV',
#  'Category:Undeveloped_projects',
#  'Star_Trek:_Phase_II',
#  'Star_Trek:_Planet_of_the_Titans',
#  'Star_Trek_III_(Gene_Roddenberry)',
#  'Star_Trek:_The_First_Adventure',
#  'Star_Trek:_The_Beginning',
#  'Star_Trek_4_(alternate_reality)',
#  'Portal:TV_and_films',
#  'Star_Trek:_The_Next_Generation',
#  'William_T._Riker',
#  'Data',
#  'Geordi_La_Forge',
#  'Worf',
#  'Deanna_Troi',
#  'Beverly_Crusher',
#  'Wesley_Crusher',
#  'Natasha_Yar',
#  'USS_Enterprise_(NCC-1701-D)',
#  'USS_Enterprise_(NCC-1701-E)',
#  'Star_Trek:_Deep_Space_Nine',
#  'Benjamin_Sisko',
#  'Kira_Nerys',
#  'Miles_O%27Brien',
#  'Odo',
#  'Jadzia_Dax',
#  'Julian_Bashir',
#  'Quark',
#  'Jake_Sisko',
#  'Ezri_Dax',
#  'Deep_Space_9',
#  'Star_Trek:_Voyager',
#  'Kathryn_Janeway',
#  'Chakotay',
#  'Tuvok',
#  'Tom_Paris',
#  'B%27Elanna_Torres',
#  'Harry_Kim',
#  'The_Doctor',
#  'Neelix',
#  'Kes',
#  'USS_Voyager',
#  'Star_Trek:_Lower_Decks',
#  'Beckett_Mariner',
#  'Brad_Boimler',
#  'D%27Vana_Tendi',
#  'Sam_Rutherford',
#  'Carol_Freeman',
#  'Jack_Ransom',
#  'Shaxs',
#  'T%27Ana',
#  'USS_Cerritos',
#  'Star_Trek:_Picard',
#  'Jean-Luc_Picard',
#  'Seven_of_Nine',
#  'Agnes_Jurati',
#  'Soji_Asha',
#  'Elnor',
#  'Raffaela_Musiker',
#  'Crist%C3%B3bal_Rios',
#  'Narek',
#  'Narissa',
#  'La_Sirena',
#  'Star_Trek:_Prodigy',
#  'Dal_R%27El',
#  'Gwyn',
#  'Jankom_Pog',
#  'Zero',
#  'Rok-Tahk',
#  'Murf',
#  'Drednok',
#  'The_Diviner',
#  'Kathryn_Janeway_(hologram)',
#  'USS_Protostar',
#  'Star_Trek_films',
#  'Star_Trek_Generations',
#  'Star_Trek:_First_Contact',
#  'Star_Trek:_Insurrection',
#  'Star_Trek_Nemesis',
#  'Special:RecentChanges',
#  'Special:Community',
#  'Memory_Alpha:Introduction',
#  'Memory_Alpha:Archivists',
#  'Memory_Alpha:Administrators',
#  'Memory_Alpha:Projects',
#  'Memory_Alpha:Babel',
#  'Memory_Alpha:Ten_Forward',
#  'Memory_Alpha:Reference_Desk',
#  'Memory_Alpha:Discord',
#  'Memory_Alpha:Social_media',
#  'Memory_Alpha:Pages_to_be...',
#  'Memory_Alpha:Utilities',
#  'Memory_Alpha:Pages_needing_attention',
#  'Category:Memory_Alpha_pages_needing_citation',
#  'Category:Memory_Alpha_incomplete_articles',
#  'Category:Memory_Alpha_stubs',
#  'Category:Memory_Alpha_files_needing_attention',
#  'Category:Memory_Alpha_files_needing_citation',
#  'Special:UnusedFiles',
#  'Special:Watchlist',
#  'Special:Log',
#  'Special:NewPages',
#  'Memory_Alpha:Pages_for_deletion',
#  'Memory_Alpha:Files_for_deletion',
#  'Memory_Alpha:Peer_review',
#  'Memory_Alpha:Featured_article_nominations',
#  'Memory_Alpha:Featured_article_reviews',
#  'Memory_Alpha:Policies_and_guidelines',
#  'Memory_Alpha:Manual_of_Style',
#  'Memory_Alpha:Copyrights',
#  'Memory_Alpha:Content_policy',
#  'Memory_Alpha:Resource_policy',
#  'Memory_Alpha:Cite_your_sources',
#  'Memory_Alpha:Point_of_view',
#  'Memory_Alpha:File_use_policy',
#  'Memory_Alpha:Spoiler_policy',
#  'Memory_Alpha:FAQ',
#  'Memory_Alpha:General_FAQ',
#  'Memory_Alpha:Contributions_FAQ',
#  'Memory_Alpha:Editing_FAQ',
#  'Memory_Alpha:Content_policy_FAQ',
#  'Memory_Alpha:Resource_policy_FAQ',
#  'Memory_Alpha:Administration_FAQ',
#  'Memory_Alpha:Contact_us',
#  'Memory_Alpha:Privacy_policy',
#  'MA_Help:Contents',
#  'MA_Help:Logging_in',
#  'MA_Help:Editing',
#  'MA_Help:Edit_summary',
#  'MA_Help:Wiki_markup',
#  'MA_Help:Template',
#  'MA_Help:Category',
#  'MA_Help:Talk_pages']

# %%
# create a filter for undesired links
filter  = '(%s)' % '|'.join([
    'Category:',
    'File:',
    'Help:',
    'Memory_Alpha:',
    'Portal:',
    'action=',
    'Special:',
    'Star_Trek:',
    'Star_Trek_',
    'Talk:'
])
# remove the links that are found in the filter
tag_list = [t for t in tag_list if not re.search(filter, t)]
tag_list
# Out:
# ['#',
#  '/f',
#  'https://memory-alpha.fandom.com/wiki/Borg',
#  'https://memory-alpha.fandom.com/wiki/Cardassian_Union',
#  'https://memory-alpha.fandom.com/wiki/Dominion',
#  'https://memory-alpha.fandom.com/wiki/Ferengi_Alliance',
#  'https://memory-alpha.fandom.com/wiki/United_Federation_of_Planets',
#  'https://memory-alpha.fandom.com/wiki/Klingon_Empire',
#  'https://memory-alpha.fandom.com/wiki/Romulan_Star_Empire',
#  'https://memory-alpha.fandom.com/wiki/Vulcan',
#  'https://memory-alpha.fandom.com/wiki/Alpha_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Beta_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Gamma_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Delta_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Alternate_reality',
#  'https://memory-alpha.fandom.com/wiki/Studio_model',
#  'https://memory-alpha.fandom.com/wiki/Retroactive_continuity',
#  'https://memory-alpha.fandom.com/wiki/Deleted_scene',
#  'https://memory-alpha.fandom.com/wiki/DVD',
#  'https://memory-alpha.fandom.com/wiki/Blu-ray_Disc',
#  'https://memory-alpha.fandom.com/wiki/Digital_formats',
#  'https://memory-alpha.fandom.com/wiki/Novels',
#  'https://memory-alpha.fandom.com/wiki/Comics',
#  'https://memory-alpha.fandom.com/wiki/Calendars',
#  'https://memory-alpha.fandom.com/wiki/Jonathan_Archer',
#  'https://memory-alpha.fandom.com/wiki/T%27Pol',
#  'https://memory-alpha.fandom.com/wiki/Charles_Tucker_III',
#  'https://memory-alpha.fandom.com/wiki/Malcolm_Reed',
#  'https://memory-alpha.fandom.com/wiki/Phlox',
#  'https://memory-alpha.fandom.com/wiki/Hoshi_Sato',
#  'https://memory-alpha.fandom.com/wiki/Travis_Mayweather',
#  'https://memory-alpha.fandom.com/wiki/Thy%27lek_Shran',
#  'https://memory-alpha.fandom.com/wiki/Maxwell_Forrest',
#  'https://memory-alpha.fandom.com/wiki/Enterprise_(NX-01)',
#  'https://memory-alpha.fandom.com/wiki/Michael_Burnham',
#  'https://memory-alpha.fandom.com/wiki/Saru',
#  'https://memory-alpha.fandom.com/wiki/Paul_Stamets',
#  'https://memory-alpha.fandom.com/wiki/Sylvia_Tilly',
#  'https://memory-alpha.fandom.com/wiki/Hugh_Culber',
#  'https://memory-alpha.fandom.com/wiki/Nhan',
#  'https://memory-alpha.fandom.com/wiki/Adira_Tal',
#  'https://memory-alpha.fandom.com/wiki/Cleveland_Booker',
#  'https://memory-alpha.fandom.com/wiki/Philippa_Georgiou_(mirror)',
#  'https://memory-alpha.fandom.com/wiki/USS_Discovery',
#  'https://memory-alpha.fandom.com/wiki/Christopher_Pike',
#  'https://memory-alpha.fandom.com/wiki/Una',
#  'https://memory-alpha.fandom.com/wiki/James_T._Kirk',
#  'https://memory-alpha.fandom.com/wiki/Spock',
#  'https://memory-alpha.fandom.com/wiki/Leonard_McCoy',
#  'https://memory-alpha.fandom.com/wiki/Montgomery_Scott',
#  'https://memory-alpha.fandom.com/wiki/Hikaru_Sulu',
#  'https://memory-alpha.fandom.com/wiki/Nyota_Uhura',
#  'https://memory-alpha.fandom.com/wiki/Pavel_Chekov',
#  'https://memory-alpha.fandom.com/wiki/Christine_Chapel',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701)',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-A)',
#  'https://memory-alpha.fandom.com/wiki/James_T._Kirk_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Spock_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Leonard_McCoy_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Nyota_Uhura_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Montgomery_Scott_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Hikaru_Sulu_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Pavel_Chekov_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Christopher_Pike_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701_alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-A_alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/William_T._Riker',
#  'https://memory-alpha.fandom.com/wiki/Data',
#  'https://memory-alpha.fandom.com/wiki/Geordi_La_Forge',
#  'https://memory-alpha.fandom.com/wiki/Worf',
#  'https://memory-alpha.fandom.com/wiki/Deanna_Troi',
#  'https://memory-alpha.fandom.com/wiki/Beverly_Crusher',
#  'https://memory-alpha.fandom.com/wiki/Wesley_Crusher',
#  'https://memory-alpha.fandom.com/wiki/Natasha_Yar',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-D)',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-E)',
#  'https://memory-alpha.fandom.com/wiki/Benjamin_Sisko',
#  'https://memory-alpha.fandom.com/wiki/Kira_Nerys',
#  'https://memory-alpha.fandom.com/wiki/Miles_O%27Brien',
#  'https://memory-alpha.fandom.com/wiki/Odo',
#  'https://memory-alpha.fandom.com/wiki/Jadzia_Dax',
#  'https://memory-alpha.fandom.com/wiki/Julian_Bashir',
#  'https://memory-alpha.fandom.com/wiki/Quark',
#  'https://memory-alpha.fandom.com/wiki/Jake_Sisko',
#  'https://memory-alpha.fandom.com/wiki/Ezri_Dax',
#  'https://memory-alpha.fandom.com/wiki/Deep_Space_9',
#  'https://memory-alpha.fandom.com/wiki/Kathryn_Janeway',
#  'https://memory-alpha.fandom.com/wiki/Chakotay',
#  'https://memory-alpha.fandom.com/wiki/Tuvok',
#  'https://memory-alpha.fandom.com/wiki/Tom_Paris',
#  'https://memory-alpha.fandom.com/wiki/B%27Elanna_Torres',
#  'https://memory-alpha.fandom.com/wiki/Harry_Kim',
#  'https://memory-alpha.fandom.com/wiki/The_Doctor',
#  'https://memory-alpha.fandom.com/wiki/Neelix',
#  'https://memory-alpha.fandom.com/wiki/Kes',
#  'https://memory-alpha.fandom.com/wiki/USS_Voyager',
#  'https://memory-alpha.fandom.com/wiki/Beckett_Mariner',
#  'https://memory-alpha.fandom.com/wiki/Brad_Boimler',
#  'https://memory-alpha.fandom.com/wiki/D%27Vana_Tendi',
#  'https://memory-alpha.fandom.com/wiki/Sam_Rutherford',
#  'https://memory-alpha.fandom.com/wiki/Carol_Freeman',
#  'https://memory-alpha.fandom.com/wiki/Jack_Ransom',
#  'https://memory-alpha.fandom.com/wiki/Shaxs',
#  'https://memory-alpha.fandom.com/wiki/T%27Ana',
#  'https://memory-alpha.fandom.com/wiki/USS_Cerritos',
#  'https://memory-alpha.fandom.com/wiki/Jean-Luc_Picard',
#  'https://memory-alpha.fandom.com/wiki/Seven_of_Nine',
#  'https://memory-alpha.fandom.com/wiki/Agnes_Jurati',
#  'https://memory-alpha.fandom.com/wiki/Soji_Asha',
#  'https://memory-alpha.fandom.com/wiki/Elnor',
#  'https://memory-alpha.fandom.com/wiki/Raffaela_Musiker',
#  'https://memory-alpha.fandom.com/wiki/Crist%C3%B3bal_Rios',
#  'https://memory-alpha.fandom.com/wiki/Narek',
#  'https://memory-alpha.fandom.com/wiki/Narissa',
#  'https://memory-alpha.fandom.com/wiki/La_Sirena',
#  'https://memory-alpha.fandom.com/wiki/Dal_R%27El',
#  'https://memory-alpha.fandom.com/wiki/Gwyn',
#  'https://memory-alpha.fandom.com/wiki/Jankom_Pog',
#  'https://memory-alpha.fandom.com/wiki/Zero',
#  'https://memory-alpha.fandom.com/wiki/Rok-Tahk',
#  'https://memory-alpha.fandom.com/wiki/Murf',
#  'https://memory-alpha.fandom.com/wiki/Drednok',
#  'https://memory-alpha.fandom.com/wiki/The_Diviner',
#  'https://memory-alpha.fandom.com/wiki/Kathryn_Janeway_(hologram)',
#  'https://memory-alpha.fandom.com/wiki/USS_Protostar']

# %%
# remove duplicates
tag_list = list(set(tag_list))
tag_list
# Out:
# ['https://memory-alpha.fandom.com/wiki/The_Diviner',
#  'https://memory-alpha.fandom.com/wiki/Pavel_Chekov',
#  'https://memory-alpha.fandom.com/wiki/Nyota_Uhura',
#  'https://memory-alpha.fandom.com/wiki/Thy%27lek_Shran',
#  'https://memory-alpha.fandom.com/wiki/Leonard_McCoy_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Charles_Tucker_III',
#  'https://memory-alpha.fandom.com/wiki/Rok-Tahk',
#  'https://memory-alpha.fandom.com/wiki/Jake_Sisko',
#  'https://memory-alpha.fandom.com/wiki/T%27Pol',
#  'https://memory-alpha.fandom.com/wiki/DVD',
#  'https://memory-alpha.fandom.com/wiki/Jonathan_Archer',
#  'https://memory-alpha.fandom.com/wiki/D%27Vana_Tendi',
#  'https://memory-alpha.fandom.com/wiki/Dal_R%27El',
#  'https://memory-alpha.fandom.com/wiki/Hugh_Culber',
#  'https://memory-alpha.fandom.com/wiki/Deep_Space_9',
#  'https://memory-alpha.fandom.com/wiki/Enterprise_(NX-01)',
#  'https://memory-alpha.fandom.com/wiki/Soji_Asha',
#  'https://memory-alpha.fandom.com/wiki/USS_Discovery',
#  'https://memory-alpha.fandom.com/wiki/Tuvok',
#  'https://memory-alpha.fandom.com/wiki/Geordi_La_Forge',
#  'https://memory-alpha.fandom.com/wiki/Alternate_reality',
#  'https://memory-alpha.fandom.com/wiki/Murf',
#  'https://memory-alpha.fandom.com/wiki/Phlox',
#  'https://memory-alpha.fandom.com/wiki/Julian_Bashir',
#  'https://memory-alpha.fandom.com/wiki/The_Doctor',
#  'https://memory-alpha.fandom.com/wiki/Gamma_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Jack_Ransom',
#  'https://memory-alpha.fandom.com/wiki/Hoshi_Sato',
#  'https://memory-alpha.fandom.com/wiki/James_T._Kirk',
#  'https://memory-alpha.fandom.com/wiki/Studio_model',
#  'https://memory-alpha.fandom.com/wiki/Malcolm_Reed',
#  'https://memory-alpha.fandom.com/wiki/Paul_Stamets',
#  'https://memory-alpha.fandom.com/wiki/Adira_Tal',
#  'https://memory-alpha.fandom.com/wiki/Elnor',
#  'https://memory-alpha.fandom.com/wiki/Nyota_Uhura_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/La_Sirena',
#  'https://memory-alpha.fandom.com/wiki/Hikaru_Sulu_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Benjamin_Sisko',
#  'https://memory-alpha.fandom.com/wiki/Saru',
#  'https://memory-alpha.fandom.com/wiki/Christopher_Pike_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Hikaru_Sulu',
#  'https://memory-alpha.fandom.com/wiki/Sam_Rutherford',
#  'https://memory-alpha.fandom.com/wiki/Christopher_Pike',
#  'https://memory-alpha.fandom.com/wiki/Kathryn_Janeway',
#  'https://memory-alpha.fandom.com/wiki/Crist%C3%B3bal_Rios',
#  'https://memory-alpha.fandom.com/wiki/Drednok',
#  'https://memory-alpha.fandom.com/wiki/Borg',
#  'https://memory-alpha.fandom.com/wiki/Kira_Nerys',
#  'https://memory-alpha.fandom.com/wiki/Maxwell_Forrest',
#  'https://memory-alpha.fandom.com/wiki/USS_Voyager',
#  'https://memory-alpha.fandom.com/wiki/USS_Cerritos',
#  'https://memory-alpha.fandom.com/wiki/Dominion',
#  'https://memory-alpha.fandom.com/wiki/Spock',
#  'https://memory-alpha.fandom.com/wiki/Jean-Luc_Picard',
#  'https://memory-alpha.fandom.com/wiki/Ferengi_Alliance',
#  'https://memory-alpha.fandom.com/wiki/Neelix',
#  'https://memory-alpha.fandom.com/wiki/Kes',
#  'https://memory-alpha.fandom.com/wiki/Digital_formats',
#  'https://memory-alpha.fandom.com/wiki/Vulcan',
#  'https://memory-alpha.fandom.com/wiki/Blu-ray_Disc',
#  'https://memory-alpha.fandom.com/wiki/Novels',
#  'https://memory-alpha.fandom.com/wiki/Jankom_Pog',
#  'https://memory-alpha.fandom.com/wiki/Harry_Kim',
#  'https://memory-alpha.fandom.com/wiki/Cleveland_Booker',
#  'https://memory-alpha.fandom.com/wiki/Miles_O%27Brien',
#  'https://memory-alpha.fandom.com/wiki/Jadzia_Dax',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-A_alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Brad_Boimler',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-A)',
#  'https://memory-alpha.fandom.com/wiki/Romulan_Star_Empire',
#  'https://memory-alpha.fandom.com/wiki/Delta_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Carol_Freeman',
#  'https://memory-alpha.fandom.com/wiki/William_T._Riker',
#  'https://memory-alpha.fandom.com/wiki/Comics',
#  'https://memory-alpha.fandom.com/wiki/Seven_of_Nine',
#  'https://memory-alpha.fandom.com/wiki/Raffaela_Musiker',
#  'https://memory-alpha.fandom.com/wiki/Travis_Mayweather',
#  'https://memory-alpha.fandom.com/wiki/Data',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-E)',
#  'https://memory-alpha.fandom.com/wiki/Shaxs',
#  'https://memory-alpha.fandom.com/wiki/Retroactive_continuity',
#  'https://memory-alpha.fandom.com/wiki/Worf',
#  'https://memory-alpha.fandom.com/wiki/Montgomery_Scott',
#  'https://memory-alpha.fandom.com/wiki/Wesley_Crusher',
#  'https://memory-alpha.fandom.com/wiki/USS_Protostar',
#  'https://memory-alpha.fandom.com/wiki/Chakotay',
#  'https://memory-alpha.fandom.com/wiki/Natasha_Yar',
#  'https://memory-alpha.fandom.com/wiki/Odo',
#  'https://memory-alpha.fandom.com/wiki/B%27Elanna_Torres',
#  'https://memory-alpha.fandom.com/wiki/Spock_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Deanna_Troi',
#  'https://memory-alpha.fandom.com/wiki/Leonard_McCoy',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-D)',
#  'https://memory-alpha.fandom.com/wiki/Cardassian_Union',
#  'https://memory-alpha.fandom.com/wiki/James_T._Kirk_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Ezri_Dax',
#  'https://memory-alpha.fandom.com/wiki/Narissa',
#  'https://memory-alpha.fandom.com/wiki/Michael_Burnham',
#  'https://memory-alpha.fandom.com/wiki/Alpha_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701_alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Tom_Paris',
#  '#',
#  'https://memory-alpha.fandom.com/wiki/Montgomery_Scott_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Beckett_Mariner',
#  'https://memory-alpha.fandom.com/wiki/Gwyn',
#  'https://memory-alpha.fandom.com/wiki/Calendars',
#  'https://memory-alpha.fandom.com/wiki/Beta_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Una',
#  'https://memory-alpha.fandom.com/wiki/Sylvia_Tilly',
#  'https://memory-alpha.fandom.com/wiki/Klingon_Empire',
#  'https://memory-alpha.fandom.com/wiki/United_Federation_of_Planets',
#  'https://memory-alpha.fandom.com/wiki/Christine_Chapel',
#  'https://memory-alpha.fandom.com/wiki/Deleted_scene',
#  'https://memory-alpha.fandom.com/wiki/Pavel_Chekov_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Kathryn_Janeway_(hologram)',
#  'https://memory-alpha.fandom.com/wiki/Narek',
#  'https://memory-alpha.fandom.com/wiki/Philippa_Georgiou_(mirror)',
#  'https://memory-alpha.fandom.com/wiki/Beverly_Crusher',
#  'https://memory-alpha.fandom.com/wiki/Quark',
#  'https://memory-alpha.fandom.com/wiki/Zero',
#  'https://memory-alpha.fandom.com/wiki/T%27Ana',
#  'https://memory-alpha.fandom.com/wiki/Agnes_Jurati',
#  'https://memory-alpha.fandom.com/wiki/Nhan',
#  '/f',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701)']

# %%
# convert escaped sequences
tag_list = [unquote(t) for t in tag_list]
tag_list
# Out:
# ['https://memory-alpha.fandom.com/wiki/The_Diviner',
#  'https://memory-alpha.fandom.com/wiki/Pavel_Chekov',
#  'https://memory-alpha.fandom.com/wiki/Nyota_Uhura',
#  "https://memory-alpha.fandom.com/wiki/Thy'lek_Shran",
#  'https://memory-alpha.fandom.com/wiki/Leonard_McCoy_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Charles_Tucker_III',
#  'https://memory-alpha.fandom.com/wiki/Rok-Tahk',
#  'https://memory-alpha.fandom.com/wiki/Jake_Sisko',
#  "https://memory-alpha.fandom.com/wiki/T'Pol",
#  'https://memory-alpha.fandom.com/wiki/DVD',
#  'https://memory-alpha.fandom.com/wiki/Jonathan_Archer',
#  "https://memory-alpha.fandom.com/wiki/D'Vana_Tendi",
#  "https://memory-alpha.fandom.com/wiki/Dal_R'El",
#  'https://memory-alpha.fandom.com/wiki/Hugh_Culber',
#  'https://memory-alpha.fandom.com/wiki/Deep_Space_9',
#  'https://memory-alpha.fandom.com/wiki/Enterprise_(NX-01)',
#  'https://memory-alpha.fandom.com/wiki/Soji_Asha',
#  'https://memory-alpha.fandom.com/wiki/USS_Discovery',
#  'https://memory-alpha.fandom.com/wiki/Tuvok',
#  'https://memory-alpha.fandom.com/wiki/Geordi_La_Forge',
#  'https://memory-alpha.fandom.com/wiki/Alternate_reality',
#  'https://memory-alpha.fandom.com/wiki/Murf',
#  'https://memory-alpha.fandom.com/wiki/Phlox',
#  'https://memory-alpha.fandom.com/wiki/Julian_Bashir',
#  'https://memory-alpha.fandom.com/wiki/The_Doctor',
#  'https://memory-alpha.fandom.com/wiki/Gamma_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Jack_Ransom',
#  'https://memory-alpha.fandom.com/wiki/Hoshi_Sato',
#  'https://memory-alpha.fandom.com/wiki/James_T._Kirk',
#  'https://memory-alpha.fandom.com/wiki/Studio_model',
#  'https://memory-alpha.fandom.com/wiki/Malcolm_Reed',
#  'https://memory-alpha.fandom.com/wiki/Paul_Stamets',
#  'https://memory-alpha.fandom.com/wiki/Adira_Tal',
#  'https://memory-alpha.fandom.com/wiki/Elnor',
#  'https://memory-alpha.fandom.com/wiki/Nyota_Uhura_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/La_Sirena',
#  'https://memory-alpha.fandom.com/wiki/Hikaru_Sulu_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Benjamin_Sisko',
#  'https://memory-alpha.fandom.com/wiki/Saru',
#  'https://memory-alpha.fandom.com/wiki/Christopher_Pike_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Hikaru_Sulu',
#  'https://memory-alpha.fandom.com/wiki/Sam_Rutherford',
#  'https://memory-alpha.fandom.com/wiki/Christopher_Pike',
#  'https://memory-alpha.fandom.com/wiki/Kathryn_Janeway',
#  'https://memory-alpha.fandom.com/wiki/Cristóbal_Rios',
#  'https://memory-alpha.fandom.com/wiki/Drednok',
#  'https://memory-alpha.fandom.com/wiki/Borg',
#  'https://memory-alpha.fandom.com/wiki/Kira_Nerys',
#  'https://memory-alpha.fandom.com/wiki/Maxwell_Forrest',
#  'https://memory-alpha.fandom.com/wiki/USS_Voyager',
#  'https://memory-alpha.fandom.com/wiki/USS_Cerritos',
#  'https://memory-alpha.fandom.com/wiki/Dominion',
#  'https://memory-alpha.fandom.com/wiki/Spock',
#  'https://memory-alpha.fandom.com/wiki/Jean-Luc_Picard',
#  'https://memory-alpha.fandom.com/wiki/Ferengi_Alliance',
#  'https://memory-alpha.fandom.com/wiki/Neelix',
#  'https://memory-alpha.fandom.com/wiki/Kes',
#  'https://memory-alpha.fandom.com/wiki/Digital_formats',
#  'https://memory-alpha.fandom.com/wiki/Vulcan',
#  'https://memory-alpha.fandom.com/wiki/Blu-ray_Disc',
#  'https://memory-alpha.fandom.com/wiki/Novels',
#  'https://memory-alpha.fandom.com/wiki/Jankom_Pog',
#  'https://memory-alpha.fandom.com/wiki/Harry_Kim',
#  'https://memory-alpha.fandom.com/wiki/Cleveland_Booker',
#  "https://memory-alpha.fandom.com/wiki/Miles_O'Brien",
#  'https://memory-alpha.fandom.com/wiki/Jadzia_Dax',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-A_alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Brad_Boimler',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-A)',
#  'https://memory-alpha.fandom.com/wiki/Romulan_Star_Empire',
#  'https://memory-alpha.fandom.com/wiki/Delta_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Carol_Freeman',
#  'https://memory-alpha.fandom.com/wiki/William_T._Riker',
#  'https://memory-alpha.fandom.com/wiki/Comics',
#  'https://memory-alpha.fandom.com/wiki/Seven_of_Nine',
#  'https://memory-alpha.fandom.com/wiki/Raffaela_Musiker',
#  'https://memory-alpha.fandom.com/wiki/Travis_Mayweather',
#  'https://memory-alpha.fandom.com/wiki/Data',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-E)',
#  'https://memory-alpha.fandom.com/wiki/Shaxs',
#  'https://memory-alpha.fandom.com/wiki/Retroactive_continuity',
#  'https://memory-alpha.fandom.com/wiki/Worf',
#  'https://memory-alpha.fandom.com/wiki/Montgomery_Scott',
#  'https://memory-alpha.fandom.com/wiki/Wesley_Crusher',
#  'https://memory-alpha.fandom.com/wiki/USS_Protostar',
#  'https://memory-alpha.fandom.com/wiki/Chakotay',
#  'https://memory-alpha.fandom.com/wiki/Natasha_Yar',
#  'https://memory-alpha.fandom.com/wiki/Odo',
#  "https://memory-alpha.fandom.com/wiki/B'Elanna_Torres",
#  'https://memory-alpha.fandom.com/wiki/Spock_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Deanna_Troi',
#  'https://memory-alpha.fandom.com/wiki/Leonard_McCoy',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701-D)',
#  'https://memory-alpha.fandom.com/wiki/Cardassian_Union',
#  'https://memory-alpha.fandom.com/wiki/James_T._Kirk_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Ezri_Dax',
#  'https://memory-alpha.fandom.com/wiki/Narissa',
#  'https://memory-alpha.fandom.com/wiki/Michael_Burnham',
#  'https://memory-alpha.fandom.com/wiki/Alpha_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701_alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Tom_Paris',
#  '#',
#  'https://memory-alpha.fandom.com/wiki/Montgomery_Scott_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Beckett_Mariner',
#  'https://memory-alpha.fandom.com/wiki/Gwyn',
#  'https://memory-alpha.fandom.com/wiki/Calendars',
#  'https://memory-alpha.fandom.com/wiki/Beta_Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Una',
#  'https://memory-alpha.fandom.com/wiki/Sylvia_Tilly',
#  'https://memory-alpha.fandom.com/wiki/Klingon_Empire',
#  'https://memory-alpha.fandom.com/wiki/United_Federation_of_Planets',
#  'https://memory-alpha.fandom.com/wiki/Christine_Chapel',
#  'https://memory-alpha.fandom.com/wiki/Deleted_scene',
#  'https://memory-alpha.fandom.com/wiki/Pavel_Chekov_(alternate_reality)',
#  'https://memory-alpha.fandom.com/wiki/Kathryn_Janeway_(hologram)',
#  'https://memory-alpha.fandom.com/wiki/Narek',
#  'https://memory-alpha.fandom.com/wiki/Philippa_Georgiou_(mirror)',
#  'https://memory-alpha.fandom.com/wiki/Beverly_Crusher',
#  'https://memory-alpha.fandom.com/wiki/Quark',
#  'https://memory-alpha.fandom.com/wiki/Zero',
#  "https://memory-alpha.fandom.com/wiki/T'Ana",
#  'https://memory-alpha.fandom.com/wiki/Agnes_Jurati',
#  'https://memory-alpha.fandom.com/wiki/Nhan',
#  '/f',
#  'https://memory-alpha.fandom.com/wiki/USS_Enterprise_(NCC-1701)']

# %%
# convert underscore to space
tag_list = [re.sub('_', ' ', t) for t in tag_list]
tag_list
# Out:
# ['https://memory-alpha.fandom.com/wiki/The Diviner',
#  'https://memory-alpha.fandom.com/wiki/Pavel Chekov',
#  'https://memory-alpha.fandom.com/wiki/Nyota Uhura',
#  "https://memory-alpha.fandom.com/wiki/Thy'lek Shran",
#  'https://memory-alpha.fandom.com/wiki/Leonard McCoy (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Charles Tucker III',
#  'https://memory-alpha.fandom.com/wiki/Rok-Tahk',
#  'https://memory-alpha.fandom.com/wiki/Jake Sisko',
#  "https://memory-alpha.fandom.com/wiki/T'Pol",
#  'https://memory-alpha.fandom.com/wiki/DVD',
#  'https://memory-alpha.fandom.com/wiki/Jonathan Archer',
#  "https://memory-alpha.fandom.com/wiki/D'Vana Tendi",
#  "https://memory-alpha.fandom.com/wiki/Dal R'El",
#  'https://memory-alpha.fandom.com/wiki/Hugh Culber',
#  'https://memory-alpha.fandom.com/wiki/Deep Space 9',
#  'https://memory-alpha.fandom.com/wiki/Enterprise (NX-01)',
#  'https://memory-alpha.fandom.com/wiki/Soji Asha',
#  'https://memory-alpha.fandom.com/wiki/USS Discovery',
#  'https://memory-alpha.fandom.com/wiki/Tuvok',
#  'https://memory-alpha.fandom.com/wiki/Geordi La Forge',
#  'https://memory-alpha.fandom.com/wiki/Alternate reality',
#  'https://memory-alpha.fandom.com/wiki/Murf',
#  'https://memory-alpha.fandom.com/wiki/Phlox',
#  'https://memory-alpha.fandom.com/wiki/Julian Bashir',
#  'https://memory-alpha.fandom.com/wiki/The Doctor',
#  'https://memory-alpha.fandom.com/wiki/Gamma Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Jack Ransom',
#  'https://memory-alpha.fandom.com/wiki/Hoshi Sato',
#  'https://memory-alpha.fandom.com/wiki/James T. Kirk',
#  'https://memory-alpha.fandom.com/wiki/Studio model',
#  'https://memory-alpha.fandom.com/wiki/Malcolm Reed',
#  'https://memory-alpha.fandom.com/wiki/Paul Stamets',
#  'https://memory-alpha.fandom.com/wiki/Adira Tal',
#  'https://memory-alpha.fandom.com/wiki/Elnor',
#  'https://memory-alpha.fandom.com/wiki/Nyota Uhura (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/La Sirena',
#  'https://memory-alpha.fandom.com/wiki/Hikaru Sulu (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Benjamin Sisko',
#  'https://memory-alpha.fandom.com/wiki/Saru',
#  'https://memory-alpha.fandom.com/wiki/Christopher Pike (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Hikaru Sulu',
#  'https://memory-alpha.fandom.com/wiki/Sam Rutherford',
#  'https://memory-alpha.fandom.com/wiki/Christopher Pike',
#  'https://memory-alpha.fandom.com/wiki/Kathryn Janeway',
#  'https://memory-alpha.fandom.com/wiki/Cristóbal Rios',
#  'https://memory-alpha.fandom.com/wiki/Drednok',
#  'https://memory-alpha.fandom.com/wiki/Borg',
#  'https://memory-alpha.fandom.com/wiki/Kira Nerys',
#  'https://memory-alpha.fandom.com/wiki/Maxwell Forrest',
#  'https://memory-alpha.fandom.com/wiki/USS Voyager',
#  'https://memory-alpha.fandom.com/wiki/USS Cerritos',
#  'https://memory-alpha.fandom.com/wiki/Dominion',
#  'https://memory-alpha.fandom.com/wiki/Spock',
#  'https://memory-alpha.fandom.com/wiki/Jean-Luc Picard',
#  'https://memory-alpha.fandom.com/wiki/Ferengi Alliance',
#  'https://memory-alpha.fandom.com/wiki/Neelix',
#  'https://memory-alpha.fandom.com/wiki/Kes',
#  'https://memory-alpha.fandom.com/wiki/Digital formats',
#  'https://memory-alpha.fandom.com/wiki/Vulcan',
#  'https://memory-alpha.fandom.com/wiki/Blu-ray Disc',
#  'https://memory-alpha.fandom.com/wiki/Novels',
#  'https://memory-alpha.fandom.com/wiki/Jankom Pog',
#  'https://memory-alpha.fandom.com/wiki/Harry Kim',
#  'https://memory-alpha.fandom.com/wiki/Cleveland Booker',
#  "https://memory-alpha.fandom.com/wiki/Miles O'Brien",
#  'https://memory-alpha.fandom.com/wiki/Jadzia Dax',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-A alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Brad Boimler',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-A)',
#  'https://memory-alpha.fandom.com/wiki/Romulan Star Empire',
#  'https://memory-alpha.fandom.com/wiki/Delta Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Carol Freeman',
#  'https://memory-alpha.fandom.com/wiki/William T. Riker',
#  'https://memory-alpha.fandom.com/wiki/Comics',
#  'https://memory-alpha.fandom.com/wiki/Seven of Nine',
#  'https://memory-alpha.fandom.com/wiki/Raffaela Musiker',
#  'https://memory-alpha.fandom.com/wiki/Travis Mayweather',
#  'https://memory-alpha.fandom.com/wiki/Data',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-E)',
#  'https://memory-alpha.fandom.com/wiki/Shaxs',
#  'https://memory-alpha.fandom.com/wiki/Retroactive continuity',
#  'https://memory-alpha.fandom.com/wiki/Worf',
#  'https://memory-alpha.fandom.com/wiki/Montgomery Scott',
#  'https://memory-alpha.fandom.com/wiki/Wesley Crusher',
#  'https://memory-alpha.fandom.com/wiki/USS Protostar',
#  'https://memory-alpha.fandom.com/wiki/Chakotay',
#  'https://memory-alpha.fandom.com/wiki/Natasha Yar',
#  'https://memory-alpha.fandom.com/wiki/Odo',
#  "https://memory-alpha.fandom.com/wiki/B'Elanna Torres",
#  'https://memory-alpha.fandom.com/wiki/Spock (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Deanna Troi',
#  'https://memory-alpha.fandom.com/wiki/Leonard McCoy',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-D)',
#  'https://memory-alpha.fandom.com/wiki/Cardassian Union',
#  'https://memory-alpha.fandom.com/wiki/James T. Kirk (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Ezri Dax',
#  'https://memory-alpha.fandom.com/wiki/Narissa',
#  'https://memory-alpha.fandom.com/wiki/Michael Burnham',
#  'https://memory-alpha.fandom.com/wiki/Alpha Quadrant',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701 alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Tom Paris',
#  '#',
#  'https://memory-alpha.fandom.com/wiki/Montgomery Scott (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Beckett Mariner',
#  'https://memory-alpha.fandom.com/wiki/Gwyn',
#  'https://memory-alpha.fandom.com/wiki/Calendars',
#  'https://memory-alpha.fandom.com/wiki/Beta Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Una',
#  'https://memory-alpha.fandom.com/wiki/Sylvia Tilly',
#  'https://memory-alpha.fandom.com/wiki/Klingon Empire',
#  'https://memory-alpha.fandom.com/wiki/United Federation of Planets',
#  'https://memory-alpha.fandom.com/wiki/Christine Chapel',
#  'https://memory-alpha.fandom.com/wiki/Deleted scene',
#  'https://memory-alpha.fandom.com/wiki/Pavel Chekov (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Kathryn Janeway (hologram)',
#  'https://memory-alpha.fandom.com/wiki/Narek',
#  'https://memory-alpha.fandom.com/wiki/Philippa Georgiou (mirror)',
#  'https://memory-alpha.fandom.com/wiki/Beverly Crusher',
#  'https://memory-alpha.fandom.com/wiki/Quark',
#  'https://memory-alpha.fandom.com/wiki/Zero',
#  "https://memory-alpha.fandom.com/wiki/T'Ana",
#  'https://memory-alpha.fandom.com/wiki/Agnes Jurati',
#  'https://memory-alpha.fandom.com/wiki/Nhan',
#  '/f',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701)']

# %%
# order the list
tag_list.sort()
tag_list
# Out:
# ['#',
#  '/f',
#  'https://memory-alpha.fandom.com/wiki/Adira Tal',
#  'https://memory-alpha.fandom.com/wiki/Agnes Jurati',
#  'https://memory-alpha.fandom.com/wiki/Alpha Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Alternate reality',
#  "https://memory-alpha.fandom.com/wiki/B'Elanna Torres",
#  'https://memory-alpha.fandom.com/wiki/Beckett Mariner',
#  'https://memory-alpha.fandom.com/wiki/Benjamin Sisko',
#  'https://memory-alpha.fandom.com/wiki/Beta Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Beverly Crusher',
#  'https://memory-alpha.fandom.com/wiki/Blu-ray Disc',
#  'https://memory-alpha.fandom.com/wiki/Borg',
#  'https://memory-alpha.fandom.com/wiki/Brad Boimler',
#  'https://memory-alpha.fandom.com/wiki/Calendars',
#  'https://memory-alpha.fandom.com/wiki/Cardassian Union',
#  'https://memory-alpha.fandom.com/wiki/Carol Freeman',
#  'https://memory-alpha.fandom.com/wiki/Chakotay',
#  'https://memory-alpha.fandom.com/wiki/Charles Tucker III',
#  'https://memory-alpha.fandom.com/wiki/Christine Chapel',
#  'https://memory-alpha.fandom.com/wiki/Christopher Pike',
#  'https://memory-alpha.fandom.com/wiki/Christopher Pike (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Cleveland Booker',
#  'https://memory-alpha.fandom.com/wiki/Comics',
#  'https://memory-alpha.fandom.com/wiki/Cristóbal Rios',
#  "https://memory-alpha.fandom.com/wiki/D'Vana Tendi",
#  'https://memory-alpha.fandom.com/wiki/DVD',
#  "https://memory-alpha.fandom.com/wiki/Dal R'El",
#  'https://memory-alpha.fandom.com/wiki/Data',
#  'https://memory-alpha.fandom.com/wiki/Deanna Troi',
#  'https://memory-alpha.fandom.com/wiki/Deep Space 9',
#  'https://memory-alpha.fandom.com/wiki/Deleted scene',
#  'https://memory-alpha.fandom.com/wiki/Delta Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Digital formats',
#  'https://memory-alpha.fandom.com/wiki/Dominion',
#  'https://memory-alpha.fandom.com/wiki/Drednok',
#  'https://memory-alpha.fandom.com/wiki/Elnor',
#  'https://memory-alpha.fandom.com/wiki/Enterprise (NX-01)',
#  'https://memory-alpha.fandom.com/wiki/Ezri Dax',
#  'https://memory-alpha.fandom.com/wiki/Ferengi Alliance',
#  'https://memory-alpha.fandom.com/wiki/Gamma Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Geordi La Forge',
#  'https://memory-alpha.fandom.com/wiki/Gwyn',
#  'https://memory-alpha.fandom.com/wiki/Harry Kim',
#  'https://memory-alpha.fandom.com/wiki/Hikaru Sulu',
#  'https://memory-alpha.fandom.com/wiki/Hikaru Sulu (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Hoshi Sato',
#  'https://memory-alpha.fandom.com/wiki/Hugh Culber',
#  'https://memory-alpha.fandom.com/wiki/Jack Ransom',
#  'https://memory-alpha.fandom.com/wiki/Jadzia Dax',
#  'https://memory-alpha.fandom.com/wiki/Jake Sisko',
#  'https://memory-alpha.fandom.com/wiki/James T. Kirk',
#  'https://memory-alpha.fandom.com/wiki/James T. Kirk (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Jankom Pog',
#  'https://memory-alpha.fandom.com/wiki/Jean-Luc Picard',
#  'https://memory-alpha.fandom.com/wiki/Jonathan Archer',
#  'https://memory-alpha.fandom.com/wiki/Julian Bashir',
#  'https://memory-alpha.fandom.com/wiki/Kathryn Janeway',
#  'https://memory-alpha.fandom.com/wiki/Kathryn Janeway (hologram)',
#  'https://memory-alpha.fandom.com/wiki/Kes',
#  'https://memory-alpha.fandom.com/wiki/Kira Nerys',
#  'https://memory-alpha.fandom.com/wiki/Klingon Empire',
#  'https://memory-alpha.fandom.com/wiki/La Sirena',
#  'https://memory-alpha.fandom.com/wiki/Leonard McCoy',
#  'https://memory-alpha.fandom.com/wiki/Leonard McCoy (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Malcolm Reed',
#  'https://memory-alpha.fandom.com/wiki/Maxwell Forrest',
#  'https://memory-alpha.fandom.com/wiki/Michael Burnham',
#  "https://memory-alpha.fandom.com/wiki/Miles O'Brien",
#  'https://memory-alpha.fandom.com/wiki/Montgomery Scott',
#  'https://memory-alpha.fandom.com/wiki/Montgomery Scott (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Murf',
#  'https://memory-alpha.fandom.com/wiki/Narek',
#  'https://memory-alpha.fandom.com/wiki/Narissa',
#  'https://memory-alpha.fandom.com/wiki/Natasha Yar',
#  'https://memory-alpha.fandom.com/wiki/Neelix',
#  'https://memory-alpha.fandom.com/wiki/Nhan',
#  'https://memory-alpha.fandom.com/wiki/Novels',
#  'https://memory-alpha.fandom.com/wiki/Nyota Uhura',
#  'https://memory-alpha.fandom.com/wiki/Nyota Uhura (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Odo',
#  'https://memory-alpha.fandom.com/wiki/Paul Stamets',
#  'https://memory-alpha.fandom.com/wiki/Pavel Chekov',
#  'https://memory-alpha.fandom.com/wiki/Pavel Chekov (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Philippa Georgiou (mirror)',
#  'https://memory-alpha.fandom.com/wiki/Phlox',
#  'https://memory-alpha.fandom.com/wiki/Quark',
#  'https://memory-alpha.fandom.com/wiki/Raffaela Musiker',
#  'https://memory-alpha.fandom.com/wiki/Retroactive continuity',
#  'https://memory-alpha.fandom.com/wiki/Rok-Tahk',
#  'https://memory-alpha.fandom.com/wiki/Romulan Star Empire',
#  'https://memory-alpha.fandom.com/wiki/Sam Rutherford',
#  'https://memory-alpha.fandom.com/wiki/Saru',
#  'https://memory-alpha.fandom.com/wiki/Seven of Nine',
#  'https://memory-alpha.fandom.com/wiki/Shaxs',
#  'https://memory-alpha.fandom.com/wiki/Soji Asha',
#  'https://memory-alpha.fandom.com/wiki/Spock',
#  'https://memory-alpha.fandom.com/wiki/Spock (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Studio model',
#  'https://memory-alpha.fandom.com/wiki/Sylvia Tilly',
#  "https://memory-alpha.fandom.com/wiki/T'Ana",
#  "https://memory-alpha.fandom.com/wiki/T'Pol",
#  'https://memory-alpha.fandom.com/wiki/The Diviner',
#  'https://memory-alpha.fandom.com/wiki/The Doctor',
#  "https://memory-alpha.fandom.com/wiki/Thy'lek Shran",
#  'https://memory-alpha.fandom.com/wiki/Tom Paris',
#  'https://memory-alpha.fandom.com/wiki/Travis Mayweather',
#  'https://memory-alpha.fandom.com/wiki/Tuvok',
#  'https://memory-alpha.fandom.com/wiki/USS Cerritos',
#  'https://memory-alpha.fandom.com/wiki/USS Discovery',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701 alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701)',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-A alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-A)',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-D)',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-E)',
#  'https://memory-alpha.fandom.com/wiki/USS Protostar',
#  'https://memory-alpha.fandom.com/wiki/USS Voyager',
#  'https://memory-alpha.fandom.com/wiki/Una',
#  'https://memory-alpha.fandom.com/wiki/United Federation of Planets',
#  'https://memory-alpha.fandom.com/wiki/Vulcan',
#  'https://memory-alpha.fandom.com/wiki/Wesley Crusher',
#  'https://memory-alpha.fandom.com/wiki/William T. Riker',
#  'https://memory-alpha.fandom.com/wiki/Worf',
#  'https://memory-alpha.fandom.com/wiki/Zero']

# %% [markdown]
# ### Create a filter for unwanted types of articles

# %%
filter  = '(%s)' % '|'.join([
    'episode',
    'lternate_reality', # both Alternate_reality and alternate_reality
    'mirror',
    'rank',
    'production',
    'Season'
])
# remove the links that are found in the filter
tag_list = [t for t in tag_list if not re.search(filter, t)]
tag_list
# Out:
# ['#',
#  '/f',
#  'https://memory-alpha.fandom.com/wiki/Adira Tal',
#  'https://memory-alpha.fandom.com/wiki/Agnes Jurati',
#  'https://memory-alpha.fandom.com/wiki/Alpha Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Alternate reality',
#  "https://memory-alpha.fandom.com/wiki/B'Elanna Torres",
#  'https://memory-alpha.fandom.com/wiki/Beckett Mariner',
#  'https://memory-alpha.fandom.com/wiki/Benjamin Sisko',
#  'https://memory-alpha.fandom.com/wiki/Beta Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Beverly Crusher',
#  'https://memory-alpha.fandom.com/wiki/Blu-ray Disc',
#  'https://memory-alpha.fandom.com/wiki/Borg',
#  'https://memory-alpha.fandom.com/wiki/Brad Boimler',
#  'https://memory-alpha.fandom.com/wiki/Calendars',
#  'https://memory-alpha.fandom.com/wiki/Cardassian Union',
#  'https://memory-alpha.fandom.com/wiki/Carol Freeman',
#  'https://memory-alpha.fandom.com/wiki/Chakotay',
#  'https://memory-alpha.fandom.com/wiki/Charles Tucker III',
#  'https://memory-alpha.fandom.com/wiki/Christine Chapel',
#  'https://memory-alpha.fandom.com/wiki/Christopher Pike',
#  'https://memory-alpha.fandom.com/wiki/Christopher Pike (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Cleveland Booker',
#  'https://memory-alpha.fandom.com/wiki/Comics',
#  'https://memory-alpha.fandom.com/wiki/Cristóbal Rios',
#  "https://memory-alpha.fandom.com/wiki/D'Vana Tendi",
#  'https://memory-alpha.fandom.com/wiki/DVD',
#  "https://memory-alpha.fandom.com/wiki/Dal R'El",
#  'https://memory-alpha.fandom.com/wiki/Data',
#  'https://memory-alpha.fandom.com/wiki/Deanna Troi',
#  'https://memory-alpha.fandom.com/wiki/Deep Space 9',
#  'https://memory-alpha.fandom.com/wiki/Deleted scene',
#  'https://memory-alpha.fandom.com/wiki/Delta Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Digital formats',
#  'https://memory-alpha.fandom.com/wiki/Dominion',
#  'https://memory-alpha.fandom.com/wiki/Drednok',
#  'https://memory-alpha.fandom.com/wiki/Elnor',
#  'https://memory-alpha.fandom.com/wiki/Enterprise (NX-01)',
#  'https://memory-alpha.fandom.com/wiki/Ezri Dax',
#  'https://memory-alpha.fandom.com/wiki/Ferengi Alliance',
#  'https://memory-alpha.fandom.com/wiki/Gamma Quadrant',
#  'https://memory-alpha.fandom.com/wiki/Geordi La Forge',
#  'https://memory-alpha.fandom.com/wiki/Gwyn',
#  'https://memory-alpha.fandom.com/wiki/Harry Kim',
#  'https://memory-alpha.fandom.com/wiki/Hikaru Sulu',
#  'https://memory-alpha.fandom.com/wiki/Hikaru Sulu (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Hoshi Sato',
#  'https://memory-alpha.fandom.com/wiki/Hugh Culber',
#  'https://memory-alpha.fandom.com/wiki/Jack Ransom',
#  'https://memory-alpha.fandom.com/wiki/Jadzia Dax',
#  'https://memory-alpha.fandom.com/wiki/Jake Sisko',
#  'https://memory-alpha.fandom.com/wiki/James T. Kirk',
#  'https://memory-alpha.fandom.com/wiki/James T. Kirk (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Jankom Pog',
#  'https://memory-alpha.fandom.com/wiki/Jean-Luc Picard',
#  'https://memory-alpha.fandom.com/wiki/Jonathan Archer',
#  'https://memory-alpha.fandom.com/wiki/Julian Bashir',
#  'https://memory-alpha.fandom.com/wiki/Kathryn Janeway',
#  'https://memory-alpha.fandom.com/wiki/Kathryn Janeway (hologram)',
#  'https://memory-alpha.fandom.com/wiki/Kes',
#  'https://memory-alpha.fandom.com/wiki/Kira Nerys',
#  'https://memory-alpha.fandom.com/wiki/Klingon Empire',
#  'https://memory-alpha.fandom.com/wiki/La Sirena',
#  'https://memory-alpha.fandom.com/wiki/Leonard McCoy',
#  'https://memory-alpha.fandom.com/wiki/Leonard McCoy (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Malcolm Reed',
#  'https://memory-alpha.fandom.com/wiki/Maxwell Forrest',
#  'https://memory-alpha.fandom.com/wiki/Michael Burnham',
#  "https://memory-alpha.fandom.com/wiki/Miles O'Brien",
#  'https://memory-alpha.fandom.com/wiki/Montgomery Scott',
#  'https://memory-alpha.fandom.com/wiki/Montgomery Scott (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Murf',
#  'https://memory-alpha.fandom.com/wiki/Narek',
#  'https://memory-alpha.fandom.com/wiki/Narissa',
#  'https://memory-alpha.fandom.com/wiki/Natasha Yar',
#  'https://memory-alpha.fandom.com/wiki/Neelix',
#  'https://memory-alpha.fandom.com/wiki/Nhan',
#  'https://memory-alpha.fandom.com/wiki/Novels',
#  'https://memory-alpha.fandom.com/wiki/Nyota Uhura',
#  'https://memory-alpha.fandom.com/wiki/Nyota Uhura (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Odo',
#  'https://memory-alpha.fandom.com/wiki/Paul Stamets',
#  'https://memory-alpha.fandom.com/wiki/Pavel Chekov',
#  'https://memory-alpha.fandom.com/wiki/Pavel Chekov (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Phlox',
#  'https://memory-alpha.fandom.com/wiki/Quark',
#  'https://memory-alpha.fandom.com/wiki/Raffaela Musiker',
#  'https://memory-alpha.fandom.com/wiki/Retroactive continuity',
#  'https://memory-alpha.fandom.com/wiki/Rok-Tahk',
#  'https://memory-alpha.fandom.com/wiki/Romulan Star Empire',
#  'https://memory-alpha.fandom.com/wiki/Sam Rutherford',
#  'https://memory-alpha.fandom.com/wiki/Saru',
#  'https://memory-alpha.fandom.com/wiki/Seven of Nine',
#  'https://memory-alpha.fandom.com/wiki/Shaxs',
#  'https://memory-alpha.fandom.com/wiki/Soji Asha',
#  'https://memory-alpha.fandom.com/wiki/Spock',
#  'https://memory-alpha.fandom.com/wiki/Spock (alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/Studio model',
#  'https://memory-alpha.fandom.com/wiki/Sylvia Tilly',
#  "https://memory-alpha.fandom.com/wiki/T'Ana",
#  "https://memory-alpha.fandom.com/wiki/T'Pol",
#  'https://memory-alpha.fandom.com/wiki/The Diviner',
#  'https://memory-alpha.fandom.com/wiki/The Doctor',
#  "https://memory-alpha.fandom.com/wiki/Thy'lek Shran",
#  'https://memory-alpha.fandom.com/wiki/Tom Paris',
#  'https://memory-alpha.fandom.com/wiki/Travis Mayweather',
#  'https://memory-alpha.fandom.com/wiki/Tuvok',
#  'https://memory-alpha.fandom.com/wiki/USS Cerritos',
#  'https://memory-alpha.fandom.com/wiki/USS Discovery',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701 alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701)',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-A alternate reality)',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-A)',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-D)',
#  'https://memory-alpha.fandom.com/wiki/USS Enterprise (NCC-1701-E)',
#  'https://memory-alpha.fandom.com/wiki/USS Protostar',
#  'https://memory-alpha.fandom.com/wiki/USS Voyager',
#  'https://memory-alpha.fandom.com/wiki/Una',
#  'https://memory-alpha.fandom.com/wiki/United Federation of Planets',
#  'https://memory-alpha.fandom.com/wiki/Vulcan',
#  'https://memory-alpha.fandom.com/wiki/Wesley Crusher',
#  'https://memory-alpha.fandom.com/wiki/William T. Riker',
#  'https://memory-alpha.fandom.com/wiki/Worf',
#  'https://memory-alpha.fandom.com/wiki/Zero']

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
