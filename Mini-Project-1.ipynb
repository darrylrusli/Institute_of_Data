# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns

from scipy import stats
from matplotlib import pyplot as plt

# %%
files = '../DATA/netflix_titles.csv'
netflix = pd.read_csv(files)
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Set 'show_id' As Index

# %%
netflix.set_index('show_id', inplace = True)
netflix.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
netflix.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # Rename Columns

# %%
netflix = netflix.rename(columns = {
    'date_added' : 'release date',
    'release_year' : 'release year',
    'listed_in' : 'listed in'
})

netflix.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                release date  release year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %% [markdown]
# # Check Columns

# %%
netflix.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'release date',
#        'release year', 'rating', 'duration', 'listed in', 'description'],
#       dtype='object')

# %% [markdown]
# # Check Data Type

# %%
netflix.dtypes
# Out:
# type            object
# title           object
# director        object
# cast            object
# country         object
# release date    object
# release year     int64
# rating          object
# duration        object
# listed in       object
# description     object
# dtype: object

# %% [markdown]
# # Check Data Shape

# %%
netflix.shape
# Out:
# (8807, 11)

# %% [markdown]
# # Check Null Values

# %%
netflix.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# release date      98
# release year       0
# rating             4
# duration           3
# listed in          0
# description        0
# dtype: int64

# %%
d_format = '%B %d, %Y'
netflix['release date']= pd.to_datetime(netflix['release date'], format = d_format, errors = 'coerce', dayfirst = True)

# %%
netflix.dtypes
# Out:
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# release date    datetime64[ns]
# release year             int64
# rating                  object
# duration                object
# listed in               object
# description             object
# dtype: object

# %%
netflix.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#         release date  release year rating   duration  \
# show_id
# s1        2021-09-25          2020  PG-13     90 min
# ...

# %%
netflix['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
def replace_rating_value(x):
    if (x == 'PG-13'
        or x == 'TV-MA'
        or x == 'PG'
        or x == 'TV-14'
        or x == 'TV-PG'
        or x == 'TV-Y'
        or x == 'TV-Y7'
        or x == 'R'
        or x == 'TV-G'
        or x == 'G'
        or x == 'NC-17'):
        x = x
    else:

# %%
netflix['rating'] =
